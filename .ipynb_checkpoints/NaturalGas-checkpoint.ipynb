# %% [markdown]
# ## Description
#
# * This dataset contains datas from 6 US states.
# * It provides information on various variables related to natural gas consumption and prices, as well as other relevant factors.
# * The findings of this project have implications for utility companies and consumers.
# * Understanding natural gas consumption and price dynamics informs energy saving and pricing strategies
#
# #### Features
# * State: State abbreviation
# * State Code: State Code
# * Year: Year
# * Consumption: Consumption of natural gas by the residential sector
# * Price: Price of natural gas
# * Electricity Price: Price of electricity
# * Distillate Fuel Oil Price: Price of distillate fuel oil
# * Liquefied Petroleum Gas Price: Price of liquefied petroleum gas
# * Heating Degree Days: A measure of heating needs
# * Income: Real per-capita personal income

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("NaturalGas.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 state  statecode  year  consumption  price  eprice  oprice  \
# 0           1    NY         35  1967       313656   1.42    2.98    7.40
# 1           2    NY         35  1968       319282   1.38    2.91    7.77
# 2           3    NY         35  1969       331326   1.37    2.84    7.96
# 3           4    NY         35  1970       346533   1.40    2.87    8.33
# 4           5    NY         35  1971       352085   1.50    3.07    8.80
#
#    lprice  heating    income
# 0    1.47     6262  10903.75
# 1    1.42     6125  11370.02
# 2    1.38     6040  11578.68
# 3    1.37     6085  11586.77
# 4    1.40     5907  11657.42

# %%
df.shape
# Out:
# (138, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138 entries, 0 to 137
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   138 non-null    int64
#  1   state        138 non-null    object
#  2   statecode    138 non-null    int64
#  3   year         138 non-null    int64
#  4   consumption  138 non-null    int64
#  5   price        138 non-null    float64
#  6   eprice       138 non-null    float64
#  7   oprice       138 non-null    float64
#  8   lprice       138 non-null    float64
#  9   heating      138 non-null    int64
#  10  income       138 non-null    float64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 12.0+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0     0
# state          0
# statecode      0
# year           0
# consumption    0
# price          0
# eprice         0
# oprice         0
# lprice         0
# heating        0
# income         0
# dtype: int64

# %%
df=df.drop(columns=["Unnamed: 0","heating","statecode"],axis=1)

# %%
df
# Out:
#     state  year  consumption  price  eprice  oprice  lprice    income
# 0      NY  1967       313656   1.42    2.98    7.40    1.47  10903.75
# 1      NY  1968       319282   1.38    2.91    7.77    1.42  11370.02
# 2      NY  1969       331326   1.37    2.84    7.96    1.38  11578.68
# 3      NY  1970       346533   1.40    2.87    8.33    1.37  11586.77
# 4      NY  1971       352085   1.50    3.07    8.80    1.40  11657.42
# ..    ...   ...          ...    ...     ...     ...     ...       ...
# 133    CA  1985       527495   5.72    7.78   30.58    5.84  14368.46
# 134    CA  1986       464307   5.14    7.95   44.15    5.72  14580.77
# 135    CA  1987       503473   5.26    8.03   35.24    5.14  14915.05
# 136    CA  1988       497138   5.64    8.69   34.02    5.26  15340.38
# 137    CA  1989       514276   5.59    9.45   44.44    5.64  15532.93
#
# [138 rows x 8 columns]

# %%
df.describe()
# Out:
#               year    consumption       price      eprice      oprice  \
# count   138.000000     138.000000  138.000000  138.000000  138.000000
# mean   1978.000000  252901.478261    3.422319    5.053551   24.635580
# std       6.657415  184478.131559    2.169215    2.577859   15.401018
# min    1967.000000    9430.000000    0.680000    1.980000    5.010000
# 25%    1972.000000   49103.500000    1.380000    2.432500    8.240000
# 50%    1978.000000  300835.500000    2.775000    4.520000   19.865000
# 75%    1984.000000  346428.750000    5.310000    7.282500   40.102500
# max    1989.000000  637289.000000    8.060000   10.860000   51.730000
#
#            lprice        income
# count  138.000000    138.000000
# mean     3.207681  11193.235652
# std      2.124937   1906.726093
# min      0.680000   7465.340000
# 25%      1.257500   9637.165000
# 50%      2.615000  11367.460000
# 75%      5.192500  12125.335000
# max      7.870000  16425.330000

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [state, year, consumption, price, eprice, oprice, lprice, income]
# Index: []

# %%
corr=df.iloc[:,1:]
sns.heatmap(corr.corr(), cmap="YlGnBu", annot=True) 
plt.show()

# %%
df.state.value_counts()
# Out:
# NY    23
# FL    23
# MI    23
# TX    23
# UT    23
# CA    23
# Name: state, dtype: int64

# %%
df.year.unique()
# Out:
# array([1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977,
#        1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988,
#        1989], dtype=int64)

# %%
features=["consumption","price","eprice","oprice","lprice","income"]

# %%
for i in features:
    sns.lineplot(x='year', y=i, data=df,linewidth=2.5)
    plt.show()

# %%
features=["consumption","price","eprice","oprice","lprice","income"]

# %%
for i in features:
    sns.catplot(x="state",y=i,data=df,jitter=False)

# %%
df[df["state"]=="NY"][["year","price"]].max()
# Out:
# year     1989.00
# price       7.87
# dtype: float64

# %%
df.groupby("state").mean()["consumption"]
# Out:
# state
# CA    545725.000000
# FL     14736.869565
# MI    340548.695652
# NY    336216.782609
# TX    230214.521739
# UT     49967.000000
# Name: consumption, dtype: float64

# %%
df.groupby("year")["income"].max()
# Out:
# year
# 1967    10903.75
# 1968    11370.02
# 1969    11578.68
# 1970    11586.77
# 1971    11657.42
# 1972    11860.80
# 1973    11943.15
# 1974    11951.04
# 1975    11721.46
# 1976    12097.57
# 1977    12385.88
# 1978    12927.19
# 1979    13273.28
# 1980    13491.37
# 1981    13593.27
# 1982    13236.20
# 1983    13339.57
# 1984    13953.85
# 1985    14368.46
# 1986    14580.77
# 1987    15047.09
# 1988    15946.92
# 1989    16425.33
# Name: income, dtype: float64

# %%
df.groupby("state")["income"].max()
# Out:
# state
# CA    15532.93
# FL    13754.75
# MI    13596.79
# NY    16425.33
# TX    12238.59
# UT    10194.32
# Name: income, dtype: float64

# %%
labels=df["state"].unique()
views=df.groupby("state")["consumption"].sum()
plt.pie(views,labels=labels,autopct="%1.1f%%",shadow=True,wedgeprops={"width":0.3})
plt.show()

# %%
labels=df["year"].unique()
views=df.groupby("year")["consumption"].sum()
plt.pie(views,labels=labels,autopct="%1.1f%%",shadow=True,wedgeprops={"width":0.3})
plt.show()

# %%
labels=df["state"].unique()
views=df.groupby("state")["price"].mean()
plt.pie(views,labels=labels,autopct="%1.1f%%",shadow=True,wedgeprops={"width":0.3})
plt.show()

# %%
df.groupby("state")["price"].mean()
# Out:
# state
# CA    2.973913
# FL    4.579565
# MI    3.086957
# NY    4.225652
# TX    3.086957
# UT    2.580870
# Name: price, dtype: float64

# %%
df.groupby("state")["eprice"].mean()
# Out:
# state
# CA    4.889565
# FL    4.845217
# MI    4.728696
# NY    6.790435
# TX    4.421304
# UT    4.646087
# Name: eprice, dtype: float64

# %%
df.groupby("year").sum()[["consumption"]]
# Out:
#       consumption
# year
# 1967      1388022
# 1968      1416472
# 1969      1503029
# 1970      1530638
# 1971      1627334
# 1972      1658321
# 1973      1606354
# 1974      1554900
# 1975      1600913
# 1976      1597890
# 1977      1490272
# 1978      1540891
# 1979      1666974
# 1980      1548096
# 1981      1467109
# 1982      1519963
# 1983      1446071
# 1984      1448216
# 1985      1473530
# 1986      1397375
# 1987      1419023
# 1988      1469999
# 1989      1529012

# %%
df[df["price"]==df["price"].max()]["state"].iloc[0]
# Out:
# 'FL'

# %%
df[df["state"]=="FL"].max()[["year","consumption"]]
# Out:
# year            1989
# consumption    21619
# dtype: object

# %%
df["price"].unique().max()
# Out:
# 8.06

# %%
df["eprice"].unique().max()
# Out:
# 10.86

# %%
df["lprice"].unique().max()
# Out:
# 7.87

# %%
df["oprice"].unique().max()
# Out:
# 51.73

# %%
sns.scatterplot(x='income', y='consumption', data=df)
plt.show()

# %%
sns.scatterplot(x='income', y='price', data=df)
plt.show()

# %%
sns.pairplot(df, hue ='state')
